# %%
import os

# Dataset root path
data_dir = '/kaggle/input/a-large-publicly-available-electrocardiography/ptb-xl-a-large-publicly-available-electrocardiography-dataset-1.0.3'

# List to store all file paths
all_files = []

# Walk through every folder and subfolder
for root, dirs, files in os.walk(data_dir):
    for f in files:
        file_path = os.path.join(root, f)
        all_files.append(file_path)

# Show total number of files
print(f"✅ Total files found: {len(all_files)}")

# Show a few sample file paths
print("\n📂 Example file paths:")
for i, path in enumerate(all_files[:15]):
    print(f"{i+1}. {path}")

# Optional: summary by folder (robust version)
folder_summary = {}
for f in all_files:
    relative_path = os.path.dirname(f).replace(data_dir, '').strip(os.sep)
    parts = relative_path.split(os.sep)
    folder = parts[0] if len(parts) > 0 and parts[0] != '' else "root"
    folder_summary[folder] = folder_summary.get(folder, 0) + 1

print("\n📊 File count by top-level folder:")
for k, v in folder_summary.items():
    print(f"{k:20s} : {v}")
# Out:
# ✅ Total files found: 87204
#
# 📂 Example file paths:
# 1. /kaggle/input/a-large-publicly-available-electrocardiography/ptb-xl-a-large-publicly-available-electrocardiography-dataset-1.0.3/SHA256SUMS.txt
# 2. /kaggle/input/a-large-publicly-available-electrocardiography/ptb-xl-a-large-publicly-available-electrocardiography-dataset-1.0.3/RECORDS
# 3. /kaggle/input/a-large-publicly-available-electrocardiography/ptb-xl-a-large-publicly-available-electrocardiography-dataset-1.0.3/example_physionet.py
# 4. /kaggle/input/a-large-publicly-available-electrocardiography/ptb-xl-a-large-publicly-available-electrocardiography-dataset-1.0.3/ptbxl_v103_changelog.txt
# 5. /kaggle/input/a-large-publicly-available-electrocardiography/ptb-xl-a-large-publicly-available-electrocardiography-dataset-1.0.3/scp_statements.csv
# 6. /kaggle/input/a-large-publicly-available-electrocardiography/ptb-xl-a-large-publicly-available-electrocardiography-dataset-1.0.3/ptbxl_database.csv
# 7. /kaggle/input/a-large-publicly-available-electrocardiography/ptb-xl-a-large-publicly-available-electrocardiography-dataset-1.0.3/LICENSE.txt
# 8. /kaggle/input/a-large-publicly-available-electrocardiography/ptb-xl-a-large-publicly-available-electrocardiography-dataset-1.0.3/ptbxl_v102_changelog.txt
# 9. /kaggle/input/a-large-publicly-available-electrocardiography/ptb-xl-a-large-publicly-available-electrocardiography-dataset-1.0.3/records500/21000/21240_hr.hea
# 10. /kaggle/input/a-large-publicly-available-electrocardiography/ptb-xl-a-large-publicly-available-electrocardiography-dataset-1.0.3/records500/21000/21428_hr.dat
# 11. /kaggle/input/a-large-publicly-available-electrocardiography/ptb-xl-a-large-publicly-available-electrocardiography-dataset-1.0.3/records500/21000/21604_hr.hea
# 12. /kaggle/input/a-large-publicly-available-electrocardiography/ptb-xl-a-large-publicly-available-electrocardiography-dataset-1.0.3/records500/21000/21437_hr.dat
# 13. /kaggle/input/a-large-publicly-available-electrocardiography/ptb-xl-a-large-publicly-available-electrocardiography-dataset-1.0.3/records500/21000/21080_hr.hea
# 14. /kaggle/input/a-large-publicly-available-electrocardiography/ptb-xl-a-large-publicly-available-electrocardiography-dataset-1.0.3/records500/21000/21694_hr.hea
# 15. /kaggle/input/a-large-publicly-available-electrocardiography/ptb-xl-a-large-publicly-available-electrocardiography-dataset-1.0.3/records500/21000/21504_hr.hea
#
# 📊 File count by top-level folder:
# root                 : 8
# records500           : 43598
# records100           : 43598

# %%
# !pip install wfdb -q

import os, ast, wfdb
import numpy as np
import pandas as pd
from tqdm import tqdm

# ---- CONFIG ----
PATH = '/kaggle/input/a-large-publicly-available-electrocardiography/ptb-xl-a-large-publicly-available-electrocardiography-dataset-1.0.3'
SAMPLING_RATE = 100  # 100 or 500 depending on which files you use
EXPECTED_SECONDS = 10  # PTB-XL is 10s normally
EXPECTED_LEN = SAMPLING_RATE * EXPECTED_SECONDS
FILE_COL = 'filename_lr' if SAMPLING_RATE == 100 else 'filename_hr'

# ---- 1) Read metadata and parse scp_codes safely ----
meta = pd.read_csv(os.path.join(PATH, 'ptbxl_database.csv'), index_col='ecg_id')
def safe_parse_scpcodes(s):
    try:
        return ast.literal_eval(s) if pd.notna(s) else {}
    except Exception:
        return {}
meta['scp_codes'] = meta['scp_codes'].apply(safe_parse_scpcodes)

# ---- 2) Load diagnostic mapping and keep only diagnostic statements ----
agg_df = pd.read_csv(os.path.join(PATH, 'scp_statements.csv'), index_col=0)
agg_df = agg_df[agg_df['diagnostic'] == 1]

def aggregate_diagnostic(y_dic):
    out = []
    for k in y_dic.keys():
        if k in agg_df.index:
            out.append(agg_df.loc[k, 'diagnostic_class'])
    return list(set(out))

meta['diagnostic_superclass'] = meta['scp_codes'].apply(aggregate_diagnostic)

# ---- 3) Keep only single-label ECGs (and reset index for easy iteration) ----
mask = meta['diagnostic_superclass'].apply(lambda x: len(x) == 1)
meta_filtered = meta[mask].copy()
# simplify to single string label
meta_filtered['diagnostic_superclass'] = meta_filtered['diagnostic_superclass'].apply(lambda x: x[0])
meta_filtered = meta_filtered.reset_index()  # optional, makes iterating easier

print("Filtered metadata samples:", len(meta_filtered))
print(meta_filtered['diagnostic_superclass'].value_counts())

# ---- 4) Load signals for *only* filtered metadata rows ----
def load_signal_safe(record_name, records_dir):
    """
    Try to load record_name using wfdb.rdsamp. Returns a 2D numpy array (T, n_leads) or None on error.
    record_name should match what's in the metadata FILE_COL (commonly record name without extension).
    """
    try:
        # wfdb accepts a path-like string; if your csv already has directory or extensions, try both approaches
        sig, fields = wfdb.rdsamp(os.path.join(records_dir, record_name))
        # sig is shape (n_samples, n_leads) as numpy array
        return sig
    except Exception:
        # try fallback: maybe csv contains full filename with extension, try removing extension or using record_name only
        base = os.path.splitext(record_name)[0]
        try:
            sig, fields = wfdb.rdsamp(os.path.join(records_dir, base))
            return sig
        except Exception as e:
            print("Could not load:", record_name, "error:", str(e))
            return None

signals = []
labels = []
failed = []
for _, row in tqdm(meta_filtered.iterrows(), total=len(meta_filtered)):
    rec_name = row[FILE_COL]
    sig = load_signal_safe(rec_name, PATH)
    if sig is None:
        failed.append(rec_name)
        continue

    # Ensure shape consistency: (n_samples, n_leads)
    # Convert dtype and pad/truncate to EXPECTED_LEN
    sig = np.asarray(sig, dtype=np.float32)
    n_samples, n_leads = sig.shape
    if n_samples < EXPECTED_LEN:
        # pad at end with zeros
        pad_len = EXPECTED_LEN - n_samples
        sig = np.pad(sig, ((0, pad_len),(0,0)), mode='constant')
    elif n_samples > EXPECTED_LEN:
        sig = sig[:EXPECTED_LEN, :]

    # Convert to (T, C) -> eventually we may want (C, T) for PyTorch, but keep (T, C) now
    signals.append(sig)
    labels.append(row['diagnostic_superclass'])

print("Loaded signals:", len(signals), "Failed:", len(failed))

# Convert to numpy arrays
# signals shape -> (N, T, C)
X_filtered = np.stack(signals).astype(np.float32)
y_filtered = pd.Series(labels)

print("X_filtered shape:", X_filtered.shape)  # (n_samples, n_timesteps, n_leads)
print("y_filtered shape:", y_filtered.shape)

# Optional: save for caching to disk so you don't re-read WFDB next time
# np.save('X_filtered.npy', X_filtered)
# y_filtered.to_csv('Y_filtered.csv', index=False)
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 kB 3.8 MB/s eta 0:00:00
# Filtered metadata samples: 16244
# diagnostic_superclass
# NORM    9069
# MI      2532
# STTC    2400
# CD      1708
# HYP      535
# Name: count, dtype: int64
# 100%|██████████| 16244/16244 [02:36<00:00, 103.67it/s]
# Loaded signals: 16244 Failed: 0
# X_filtered shape: (16244, 1000, 12)
# y_filtered shape: (16244,)

# %%
# InceptionTime-style 1D model (drop into Block A)
import torch
import torch.nn as nn
import torch.nn.functional as F

class InceptionModule1D(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_sizes=(9,19,39), bottleneck_channels=32, use_bn=True):
        """
        Inception module for 1D signals (as in InceptionTime).
        - in_channels: input channels
        - out_channels: total output channels (will be split across branches)
        - kernel_sizes: tuple of conv kernel sizes for different branches
        - bottleneck_channels: channels in bottleneck 1x1 conv (0 or None to disable)
        """
        super().__init__()
        self.use_bottleneck = bottleneck_channels is not None and bottleneck_channels > 0
        if self.use_bottleneck:
            self.bottleneck = nn.Conv1d(in_channels, bottleneck_channels, kernel_size=1, bias=False)
            in_ch = bottleneck_channels
        else:
            in_ch = in_channels

        # three conv branches with different kernel sizes
        self.conv1 = nn.Conv1d(in_ch, out_channels//4, kernel_size=kernel_sizes[0], padding=kernel_sizes[0]//2, bias=False)
        self.conv2 = nn.Conv1d(in_ch, out_channels//4, kernel_size=kernel_sizes[1], padding=kernel_sizes[1]//2, bias=False)
        self.conv3 = nn.Conv1d(in_ch, out_channels//4, kernel_size=kernel_sizes[2], padding=kernel_sizes[2]//2, bias=False)

        # maxpool branch
        self.maxpool = nn.MaxPool1d(kernel_size=3, stride=1, padding=1)
        self.conv_pool = nn.Conv1d(in_channels, out_channels//4, kernel_size=1, bias=False)

        if use_bn:
            self.bn = nn.BatchNorm1d(out_channels)
        else:
            self.bn = None
        self.relu = nn.ReLU(inplace=True)

    def forward(self, x):
        if self.use_bottleneck:
            x_b = self.bottleneck(x)
        else:
            x_b = x
        out1 = self.conv1(x_b)
        out2 = self.conv2(x_b)
        out3 = self.conv3(x_b)
        out4 = self.conv_pool(self.maxpool(x))
        out = torch.cat([out1, out2, out3, out4], dim=1)
        if self.bn is not None:
            out = self.bn(out)
        return self.relu(out)

class InceptionBlock(nn.Module):
    def __init__(self, in_channels, out_channels, n_modules=3, kernel_sizes=(9,19,39), bottleneck_channels=32, use_bn=True, dropout=0.2):
        super().__init__()
        modules = []
        ch = in_channels
        for _ in range(n_modules):
            modules.append(InceptionModule1D(ch, out_channels, kernel_sizes=kernel_sizes, bottleneck_channels=bottleneck_channels, use_bn=use_bn))
            ch = out_channels
        self.inception_stack = nn.Sequential(*modules)
        self.global_pool = nn.AdaptiveAvgPool1d(1)
        self.dropout = nn.Dropout(dropout)
        self.out_ch = out_channels

    def forward(self, x):
        x = self.inception_stack(x)
        x = self.global_pool(x).squeeze(-1)  # (B, out_ch)
        x = self.dropout(x)
        return x

class InceptionTime(nn.Module):
    def __init__(self, in_channels=12, num_classes=5, blocks=3, module_out_channels=128, n_modules_per_block=1, 
                 kernel_sizes=(9,19,39), bottleneck_channels=32, dropout=0.2):
        super().__init__()
        # stack multiple inception blocks, followed by FC
        layers = []
        ch = in_channels
        for _ in range(blocks):
            layers.append(InceptionModule1D(ch, module_out_channels, kernel_sizes=kernel_sizes, bottleneck_channels=bottleneck_channels))
            ch = module_out_channels
        self.features = nn.Sequential(*layers)
        self.global_pool = nn.AdaptiveAvgPool1d(1)
        self.dropout = nn.Dropout(dropout)
        self.fc = nn.Linear(ch, num_classes)

    def forward(self, x):
        # x: (B, C, T)
        x = self.features(x)
        x = self.global_pool(x).squeeze(-1)
        x = self.dropout(x)
        x = self.fc(x)
        return x

def build_inception_time(in_channels, num_classes, **kwargs):
    """
    Simple constructor. Example:
      model = build_inception_time(in_channels=12, num_classes=5, blocks=3, module_out_channels=128)
    """
    return InceptionTime(in_channels=in_channels, num_classes=num_classes, **kwargs)

# %%
# ---------------- Augmentation cell (paste this BEFORE Block B) ----------------
# Defines 1D signal augmentations, AugmentedDataset, and mixup helper.
# Usage: replace your train dataset creation with:
#   train_ds = AugmentedDataset(X_train, y_train, augment=True, aug_probs=None, seed=SEED)
# Keep validation/test datasets unchanged (no augmentation).

import numpy as np
import torch
from torch.utils.data import Dataset

# ---------- simple augmentations (operate on numpy arrays shaped (C, T)) ----------
def jitter(x, sigma=0.01):
    """Add Gaussian noise to entire sample (C,T)."""
    return x + np.random.normal(0, sigma, size=x.shape).astype(x.dtype)

def scaling(x, sigma=0.1):
    """Scale each channel by a factor ~ N(1, sigma)."""
    factors = np.random.normal(1.0, sigma, size=(x.shape[0], 1)).astype(x.dtype)
    return (x * factors)

def channel_dropout(x, p=0.1):
    """Zero out full channels with probability p (per sample)."""
    mask = (np.random.rand(x.shape[0]) > p).astype(x.dtype)
    return x * mask[:, None]

def random_crop_or_pad(x, crop_frac_min=0.85, crop_frac_max=1.0):
    """Randomly crop a contiguous segment and pad back to original length (keeps T constant)."""
    C, T = x.shape
    crop_frac = np.random.uniform(crop_frac_min, crop_frac_max)
    new_T = max(1, int(T * crop_frac))
    if new_T == T:
        return x
    start = np.random.randint(0, T - new_T + 1)
    cropped = x[:, start:start+new_T]
    out = np.zeros_like(x)
    if np.random.rand() < 0.5:
        out[:, :new_T] = cropped
    else:
        pos = np.random.randint(0, T - new_T + 1)
        out[:, pos:pos+new_T] = cropped
    return out

def random_shift(x, shift_max_frac=0.05):
    """Shift along time axis (zero-pad) by up to +/- shift_max_frac * T."""
    C, T = x.shape
    max_shift = int(shift_max_frac * T)
    if max_shift <= 0:
        return x
    shift = np.random.randint(-max_shift, max_shift+1)
    if shift == 0:
        return x
    out = np.zeros_like(x)
    if shift > 0:
        out[:, shift:] = x[:, :-shift]
    else:
        out[:, :shift] = x[:, -shift:]
    return out

def time_mask(x, max_mask_frac=0.1):
    """Zero a random contiguous time window up to max_mask_frac of T."""
    C, T = x.shape
    mask_len = int(np.random.uniform(0.0, max_mask_frac) * T)
    if mask_len <= 0:
        return x
    start = np.random.randint(0, T - mask_len + 1)
    x_copy = x.copy()
    x_copy[:, start:start+mask_len] = 0
    return x_copy

# ---------- optional mixup for training loop ----------
def mixup_data(x, y, alpha=0.2):
    """
    Mixup inputs and targets.
    x: torch tensor (B,C,T), y: torch tensor (B,)
    returns: mixed_x, y_a, y_b, lam
    """
    if alpha <= 0:
        return x, y, y, 1.0
    lam = np.random.beta(alpha, alpha)
    batch_size = x.size(0)
    index = torch.randperm(batch_size).to(x.device)
    mixed_x = lam * x + (1 - lam) * x[index, ...]
    y_a, y_b = y, y[index]
    return mixed_x, y_a, y_b, lam

# ---------- AugmentedDataset ----------
class AugmentedDataset(Dataset):
    """
    X: numpy array (N, C, T)
    y: array-like (N,)
    augment: bool
    aug_probs: dict with per-transform probabilities (keys: 'jitter','scaling','chan_drop','crop','shift','time_mask')
    seed: int or None for deterministic RNG per worker (useful for reproducibility)
    """
    def __init__(self, X, y, augment=True, aug_probs=None, seed=None):
        self.X = X
        self.y = np.array(y)
        self.augment = bool(augment)
        self.seed = seed
        # RNG: use RandomState to make dataset deterministic if seed provided
        self.rng = np.random.RandomState(seed) if seed is not None else np.random
        defaults = {
            'jitter': 0.5,
            'scaling': 0.5,
            'chan_drop': 0.3,
            'crop': 0.3,
            'shift': 0.3,
            'time_mask': 0.3
        }
        if aug_probs is None:
            aug_probs = defaults
        else:
            # fill missing keys
            for k,v in defaults.items():
                aug_probs.setdefault(k, v)
        self.aug_probs = aug_probs

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        x = self.X[idx].copy()   # numpy (C,T)
        y = int(self.y[idx])
        if self.augment:
            # use self.rng for reproducibility when seed provided
            if self.rng.rand() < self.aug_probs.get('jitter', 0):
                x = jitter(x, sigma=0.02)
            if self.rng.rand() < self.aug_probs.get('scaling', 0):
                x = scaling(x, sigma=0.1)
            if self.rng.rand() < self.aug_probs.get('chan_drop', 0):
                x = channel_dropout(x, p=0.2)
            if self.rng.rand() < self.aug_probs.get('crop', 0):
                x = random_crop_or_pad(x, crop_frac_min=0.85, crop_frac_max=1.0)
            if self.rng.rand() < self.aug_probs.get('shift', 0):
                x = random_shift(x, shift_max_frac=0.05)
            if self.rng.rand() < self.aug_probs.get('time_mask', 0):
                x = time_mask(x, max_mask_frac=0.08)
        return torch.from_numpy(x.astype(np.float32)), torch.tensor(y, dtype=torch.long)

# ---------- example usage (comment out if not needed) ----------
# Assuming you will run Block B after this cell and that SEED is defined:
# train_ds = AugmentedDataset(X_train, y_train, augment=True, aug_probs=None, seed=SEED)
# val_ds   = AugmentedDataset(X_val, y_val, augment=False)    # or keep SimpleSignalDataset for val/test
# test_ds  = AugmentedDataset(X_test, y_test, augment=False)
# If using mixup: inside your train_one_epoch, call mixup_data(Xb, yb, alpha=0.2) before forwarding.

# %%
# ------------------ Block B (InceptionTime, augmented, dropout head, sampler, optional mixup)
# with epoch-level plots: loss, acc, and ROC AUC ------------------
import numpy as np
import pandas as pd
import torch, torch.nn as nn, torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler
from sklearn.preprocessing import LabelEncoder, label_binarize
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, roc_auc_score, roc_curve, auc, accuracy_score
import matplotlib.pyplot as plt
from tqdm import tqdm
import copy, os, random, math

# ---------------- config ----------------
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
SEED = 42
random.seed(SEED); np.random.seed(SEED); torch.manual_seed(SEED)
# torch.backends.cudnn.deterministic = True
# torch.backends.cudnn.benchmark = False

OUT_DIR = "split_results"
os.makedirs(OUT_DIR, exist_ok=True)

# Hyperparams (tune to your GPU)
BATCH_SIZE = 256          # safer default for InceptionTime
LR = 1e-4
WEIGHT_DECAY = 1e-6
EPOCHS = 50
SPLITS = [0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90]
VAL_FRAC_FROM_TRAIN = 0.10

# Head / dropout
DROPOUT_P = 0.5
HEAD_HIDDEN = 512

# DataLoader performance
NUM_WORKERS = 4
PIN_MEMORY = True if torch.cuda.is_available() else False

# Mixup toggle
MIXUP_ALPHA = 0.2  # set 0 to disable

# Safety checks: expects InceptionTime & AugmentedDataset defined in prior cells
if 'X_filtered' not in globals() or 'y_filtered' not in globals():
    raise RuntimeError("X_filtered and y_filtered must be defined. Run the augmentation cell + data loading first.")
if 'build_inception_time' not in globals():
    raise RuntimeError("build_inception_time not found. Paste the InceptionTime implementation into Block A first.")

# ---------------- prepare labels / data ----------------
le = LabelEncoder()
y_array = le.fit_transform(np.array(y_filtered))
class_names = list(le.classes_)
n_classes = len(class_names)
print("Classes:", class_names)

# Convert X to (N, C, T)
X = X_filtered.transpose(0,2,1).astype(np.float32)
y = y_array

# ---------------- Dataset classes ----------------
class SimpleSignalDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = np.array(y)
    def __len__(self): return len(self.X)
    def __getitem__(self, idx):
        return torch.from_numpy(self.X[idx].astype(np.float32)), torch.tensor(int(self.y[idx]), dtype=torch.long)

# ---------------- training / evaluation helpers (updated for metrics) ----------------
def train_one_epoch(model, loader, optimizer, mixup_alpha=0.0):
    model.train()
    total_loss = 0.0
    all_preds = []
    all_trues = []
    for Xb, yb in loader:
        Xb, yb = Xb.to(DEVICE).float(), yb.to(DEVICE)
        optimizer.zero_grad()
        if mixup_alpha and mixup_alpha > 0:
            Xb, y_a, y_b, lam = mixup_data(Xb, yb, alpha=mixup_alpha)
            logits = model(Xb)
            loss = lam * F.cross_entropy(logits, y_a) + (1.0 - lam) * F.cross_entropy(logits, y_b)
            preds = logits.detach().argmax(dim=1).cpu().numpy()
            all_preds.append(preds)
            all_trues.append(yb.detach().cpu().numpy())
        else:
            logits = model(Xb)
            loss = F.cross_entropy(logits, yb)
            preds = logits.detach().argmax(dim=1).cpu().numpy()
            all_preds.append(preds)
            all_trues.append(yb.detach().cpu().numpy())
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * Xb.size(0)
    avg_loss = total_loss / len(loader.dataset)
    if all_preds:
        all_preds = np.concatenate(all_preds)
        all_trues = np.concatenate(all_trues)
        train_acc = float((all_preds == all_trues).mean())
    else:
        train_acc = None
    return avg_loss, train_acc

def evaluate(model, loader):
    model.eval()
    total_loss = 0.0
    preds = []
    probs = []
    trues = []
    with torch.no_grad():
        for Xb, yb in loader:
            Xb, yb = Xb.to(DEVICE).float(), yb.to(DEVICE)
            logits = model(Xb)
            loss = F.cross_entropy(logits, yb)
            total_loss += loss.item() * Xb.size(0)
            prob = torch.softmax(logits, dim=1).cpu().numpy()
            p = prob.argmax(axis=1)
            preds.append(p)
            probs.append(prob)
            trues.append(yb.cpu().numpy())
    preds = np.concatenate(preds) if preds else np.array([])
    probs = np.concatenate(probs) if probs else np.array([[]])
    trues = np.concatenate(trues) if trues else np.array([])
    avg_loss = total_loss / len(loader.dataset) if len(loader.dataset) > 0 else float('nan')
    acc = float((preds == trues).mean()) if len(trues) > 0 else None
    return avg_loss, preds, probs, trues, acc

def add_dropout_head(model, in_features=None, n_classes=None, hidden=HEAD_HIDDEN, p=DROPOUT_P):
    # works whether model.fc or model.classifier exists (InceptionTime uses .fc)
    if n_classes is None:
        raise ValueError("n_classes must be provided")
    detected = None
    if in_features is None:
        if hasattr(model, "fc") and isinstance(model.fc, nn.Linear):
            detected = model.fc.in_features
        elif hasattr(model, "classifier"):
            cls = model.classifier
            if isinstance(cls, nn.Linear):
                detected = cls.in_features
            elif isinstance(cls, nn.Sequential):
                for module in cls:
                    if isinstance(module, nn.Linear):
                        detected = module.in_features
                        break
    if in_features is None and detected is None:
        raise RuntimeError("Could not detect in_features automatically. Please pass in_features explicitly.")
    in_features = in_features or detected

    new_head = nn.Sequential(
        nn.Dropout(p=p),
        nn.Linear(in_features, hidden),
        nn.ReLU(inplace=True),
        nn.Dropout(p=p),
        nn.Linear(hidden, n_classes)
    )
    if hasattr(model, "fc"):
        model.fc = new_head
    elif hasattr(model, "classifier"):
        model.classifier = new_head
    else:
        model.classifier = new_head
    return model

def train_full_epochs(model, train_loader, val_loader, split_name,
                      epochs=EPOCHS, lr=LR, weight_decay=WEIGHT_DECAY, mixup_alpha=0.0):
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor=0.5, patience=3)
    best_val_loss = 1e9
    best_state = copy.deepcopy(model.state_dict())

    history = {
        'epoch': [],
        'train_loss': [],
        'val_loss': [],
        'train_acc': [],
        'val_acc': [],
        'val_macro_auc': []
    }

    for ep in range(1, epochs+1):
        tr_loss, tr_acc = train_one_epoch(model, train_loader, optimizer, mixup_alpha=mixup_alpha)
        val_loss, _, val_probs, val_trues, val_acc = evaluate(model, val_loader)

        try:
            if len(val_trues) > 0:
                present = np.unique(val_trues)
                if len(present) >= 2:
                    y_true_bin = label_binarize(val_trues, classes=np.arange(n_classes))
                    val_macro_auc = float(roc_auc_score(y_true_bin, val_probs, average='macro', multi_class='ovr'))
                else:
                    val_macro_auc = float('nan')
            else:
                val_macro_auc = float('nan')
        except Exception:
            val_macro_auc = float('nan')

        scheduler.step(val_loss)
        print(f"Epoch {ep:02d}/{epochs:02d} -> train_loss={tr_loss:.4f} val_loss={val_loss:.4f} "
              f"train_acc={tr_acc:.4f} val_acc={val_acc:.4f} val_macro_auc={np.nan if math.isnan(val_macro_auc) else val_macro_auc:.4f}")

        history['epoch'].append(ep)
        history['train_loss'].append(tr_loss)
        history['val_loss'].append(val_loss)
        history['train_acc'].append(tr_acc)
        history['val_acc'].append(val_acc)
        history['val_macro_auc'].append(val_macro_auc)

        if val_loss < best_val_loss - 1e-8:
            best_val_loss = val_loss
            best_state = copy.deepcopy(model.state_dict())
            torch.save(best_state, os.path.join(OUT_DIR, f"best_model_{split_name}.pth"))

    model.load_state_dict(best_state)
    return model, history

def plot_and_save_roc(y_true, y_score, classes, out_path):
    try:
        y_true_binarized = label_binarize(y_true, classes=np.arange(len(classes)))
    except Exception:
        return
    n_classes_local = y_score.shape[1]
    plt.figure(figsize=(8,6))
    lw = 2
    for i in range(n_classes_local):
        if np.sum(y_true_binarized[:, i]) == 0:
            continue
        fpr, tpr, _ = roc_curve(y_true_binarized[:, i], y_score[:, i])
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, lw=lw, label=f'{classes[i]} (AUC = {roc_auc:.3f})')
    try:
        fpr_micro, tpr_micro, _ = roc_curve(y_true_binarized.ravel(), y_score.ravel())
        auc_micro = auc(fpr_micro, tpr_micro)
        plt.plot(fpr_micro, tpr_micro, linestyle='--', label=f'Micro-average (AUC={auc_micro:.3f})')
    except Exception:
        pass
    plt.plot([0,1],[0,1],'k--', lw=1)
    plt.xlim([0.0,1.0]); plt.ylim([0.0,1.05])
    plt.xlabel('False Positive Rate'); plt.ylabel('True Positive Rate')
    plt.title('ROC Curves')
    plt.legend(loc='lower right', fontsize='small')
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(out_path, dpi=150)
    plt.close()

# ---------------- main loop over splits (with plotting) ----------------
summary_rows = []
for test_size in SPLITS:
    print("\n" + "="*60)
    train_ratio_percent = int((1-test_size)*100)
    split_name = f"{train_ratio_percent}-{int(test_size*100)}"
    print("Running split:", split_name)

    try:
        X_train_full, X_test, y_train_full, y_test = train_test_split(X, y, test_size=test_size, random_state=SEED, stratify=y)
    except Exception:
        X_train_full, X_test, y_train_full, y_test = train_test_split(X, y, test_size=test_size, random_state=SEED, stratify=None)

    try:
        X_train, X_val, y_train, y_val = train_test_split(X_train_full, y_train_full, test_size=VAL_FRAC_FROM_TRAIN, random_state=SEED, stratify=y_train_full)
    except Exception:
        X_train, X_val, y_train, y_val = train_test_split(X_train_full, y_train_full, test_size=VAL_FRAC_FROM_TRAIN, random_state=SEED, stratify=None)

    print(f"Sizes -> train: {len(X_train)} val: {len(X_val)} test: {len(X_test)}")

    # datasets
    train_ds = AugmentedDataset(X_train, y_train, augment=True, aug_probs=None, seed=SEED)
    val_ds   = SimpleSignalDataset(X_val, y_val)
    test_ds  = SimpleSignalDataset(X_test, y_test)

    # sampler for imbalance
    try:
        class_counts = np.bincount(y_train)
        inv_freq = 1.0 / (class_counts + 1e-6)
        sample_weights = inv_freq[y_train]
        sampler = WeightedRandomSampler(weights=sample_weights, num_samples=len(sample_weights), replacement=True)
        train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, sampler=sampler, num_workers=NUM_WORKERS, pin_memory=PIN_MEMORY)
    except Exception:
        train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS, pin_memory=PIN_MEMORY)

    val_loader = DataLoader(val_ds, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS, pin_memory=PIN_MEMORY)
    test_loader = DataLoader(test_ds, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS, pin_memory=PIN_MEMORY)

    # build InceptionTime model + optional dropout head
    model = build_inception_time(in_channels=X.shape[1], num_classes=n_classes,
                                 blocks=3, module_out_channels=128, bottleneck_channels=32, dropout=0.5)
    # replace final fc with dropout head for stronger regularization (autodetect)
    try:
        model = add_dropout_head(model, in_features=None, n_classes=n_classes, hidden=HEAD_HIDDEN, p=DROPOUT_P)
    except Exception as e:
        print("Auto-detect head failed:", e)
        # try to detect fc in typical attribute names
        if hasattr(model, "fc") and isinstance(model.fc, nn.Linear):
            in_feats = model.fc.in_features
        elif hasattr(model, "classifier") and isinstance(model.classifier, nn.Linear):
            in_feats = model.classifier.in_features
        else:
            # assume last channel same as module_out_channels
            in_feats = 128
        model = add_dropout_head(model, in_features=in_feats, n_classes=n_classes, hidden=HEAD_HIDDEN, p=DROPOUT_P)

    model = model.to(DEVICE)
    trainable_count = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print(f"Model params -> trainable: {trainable_count:,}")

    # train and get history
    model, history = train_full_epochs(model, train_loader, val_loader, split_name=split_name,
                                      epochs=EPOCHS, lr=LR, weight_decay=WEIGHT_DECAY, mixup_alpha=MIXUP_ALPHA)

    # save history CSV
    hist_df = pd.DataFrame(history)
    hist_csv = os.path.join(OUT_DIR, f"history_{split_name}.csv")
    hist_df.to_csv(hist_csv, index=False)
    print("Saved training history to", hist_csv)

    # plot loss curve
    plt.figure(figsize=(7,5))
    plt.plot(history['epoch'], history['train_loss'], label='train_loss')
    plt.plot(history['epoch'], history['val_loss'], label='val_loss')
    plt.xlabel('epoch'); plt.ylabel('loss'); plt.title(f'Loss - {split_name}')
    plt.legend(); plt.grid(True); plt.tight_layout()
    loss_png = os.path.join(OUT_DIR, f"loss_curve_{split_name}.png")
    plt.savefig(loss_png, dpi=150); plt.close()
    print("Saved loss curve to", loss_png)

    # plot accuracy curve
    plt.figure(figsize=(7,5))
    plt.plot(history['epoch'], history['train_acc'], label='train_acc')
    plt.plot(history['epoch'], history['val_acc'], label='val_acc')
    plt.xlabel('epoch'); plt.ylabel('accuracy'); plt.title(f'Accuracy - {split_name}')
    plt.legend(); plt.grid(True); plt.tight_layout()
    acc_png = os.path.join(OUT_DIR, f"acc_curve_{split_name}.png")
    plt.savefig(acc_png, dpi=150); plt.close()
    print("Saved accuracy curve to", acc_png)

    # plot val ROC AUC curve (macro)
    plt.figure(figsize=(7,5))
    val_aucs = [np.nan if (v is None) else (np.nan if math.isnan(v) else v) for v in history['val_macro_auc']]
    plt.plot(history['epoch'], val_aucs, marker='o', label='val_macro_auc')
    plt.xlabel('epoch'); plt.ylabel('macro ROC AUC'); plt.title(f'Validation Macro AUC - {split_name}')
    plt.ylim(0.0, 1.05); plt.grid(True); plt.legend(); plt.tight_layout()
    roc_auc_png = os.path.join(OUT_DIR, f"roc_auc_curve_{split_name}.png")
    plt.savefig(roc_auc_png, dpi=150); plt.close()
    print("Saved ROC AUC curve to", roc_auc_png)

    # --- evaluate on test set and per-class report/roc ---
    test_loss, preds, probs, trues, test_acc = evaluate(model, test_loader)
    cls_report = classification_report(trues, preds, target_names=class_names, output_dict=True, zero_division=0)
    cls_report_df = pd.DataFrame(cls_report).transpose()
    cls_report_df.to_csv(os.path.join(OUT_DIR, f"classification_report_{split_name}.csv"))
    print("\nClassification report for split", split_name)
    print(cls_report_df)

    # compute per-class AUC and macro AUC on test set
    try:
        per_class_auc = {}
        present_classes = []
        for i, cname in enumerate(class_names):
            if np.sum(trues == i) > 0:
                y_true_bin = (trues == i).astype(int)
                try:
                    this_auc = roc_auc_score(y_true_bin, probs[:, i])
                except Exception:
                    this_auc = np.nan
                per_class_auc[cname] = float(this_auc) if not np.isnan(this_auc) else None
                present_classes.append(i)
            else:
                per_class_auc[cname] = None

        if len(present_classes) >= 2:
            y_true_bin_all = label_binarize(trues, classes=np.arange(n_classes))
            macro_auc = roc_auc_score(y_true_bin_all, probs, average='macro', multi_class='ovr')
        else:
            macro_auc = None
    except Exception as e:
        print("ROC AUC computation issue:", e)
        per_class_auc = {c: None for c in class_names}
        macro_auc = None

    # save ROC curve figure for test set
    roc_path = os.path.join(OUT_DIR, f"roc_curves_{split_name}.png")
    try:
        plot_and_save_roc(trues, probs, class_names, roc_path)
    except Exception as e:
        print("Could not plot ROC:", e)

    # save final model state for this split
    torch.save(model.state_dict(), os.path.join(OUT_DIR, f"model_final_{split_name}.pth"))

    # append summary
    summary_rows.append({
        'split': split_name,
        'train_size': len(X_train),
        'val_size': len(X_val),
        'test_size': len(X_test),
        'test_loss': float(test_loss),
        'test_acc': float(test_acc) if test_acc is not None else None,
        'macro_auc': float(macro_auc) if macro_auc is not None else None,
        'per_class_auc': per_class_auc
    })

# Save summary CSV
summary_df = pd.DataFrame(summary_rows)
summary_df.to_csv(os.path.join(OUT_DIR, "summary_splits_overview.csv"), index=False)
print("\nSaved results to", OUT_DIR)
print(summary_df)
# Out:
# Classes: ['CD', 'HYP', 'MI', 'NORM', 'STTC']
#
# ============================================================
# Running split: 90-10
# Sizes -> train: 13157 val: 1462 test: 1625
# Model params -> trainable: 292,357
# Epoch 01/50 -> train_loss=1.5731 val_loss=1.5243 train_acc=0.2412 val_acc=0.3290 val_macro_auc=0.7223
# Epoch 02/50 -> train_loss=1.4581 val_loss=1.4781 train_acc=0.3133 val_acc=0.3365 val_macro_auc=0.7916
# Epoch 03/50 -> train_loss=1.3814 val_loss=1.3276 train_acc=0.3559 val_acc=0.4877 val_macro_auc=0.8410
# Epoch 04/50 -> train_loss=1.2678 val_loss=1.3374 train_acc=0.3491 val_acc=0.4309 val_macro_auc=0.8375
# Epoch 05/50 -> train_loss=1.2092 val_loss=1.1033 train_acc=0.3888 val_acc=0.6122 val_macro_auc=0.8767
# Epoch 06/50 -> train_loss=1.1809 val_loss=1.0004 train_acc=0.3405 val_acc=0.6546 val_macro_auc=0.8797
# Epoch 07/50 -> train_loss=1.1244 val_loss=0.9911 train_acc=0.3599 val_acc=0.6484 val_macro_auc=0.8850
# Epoch 08/50 -> train_loss=1.1402 val_loss=0.8424 train_acc=0.3641 val_acc=0.7298 val_macro_auc=0.9042
# Epoch 32/50 -> train_loss=1.0109 val_loss=0.7992 train_acc=0.4375 val_acc=0.7230 val_macro_auc=0.9174
# Epoch 33/50 -> train_loss=0.9520 val_loss=0.7925 train_acc=0.4107 val_acc=0.7291 val_macro_auc=0.9181
# Epoch 34/50 -> train_loss=0.9650 val_loss=0.7614 train_acc=0.5385 val_acc=0.7476 val_macro_auc=0.9223
# Epoch 35/50 -> train_loss=0.9813 val_loss=0.8098 train_acc=0.4266 val_acc=0.7161 val_macro_auc=0.9179
# Epoch 36/50 -> train_loss=0.9567 val_loss=0.7677 train_acc=0.5270 val_acc=0.7401 val_macro_auc=0.9210
# Epoch 37/50 -> train_loss=0.9621 val_loss=0.7909 train_acc=0.4574 val_acc=0.7319 val_macro_auc=0.9194
# Epoch 38/50 -> train_loss=1.0071 val_loss=0.8087 train_acc=0.5181 val_acc=0.7196 val_macro_auc=0.9176
# Epoch 39/50 -> train_loss=0.9846 val_loss=0.7866 train_acc=0.4462 val_acc=0.7298 val_macro_auc=0.9201
# Epoch 40/50 -> train_loss=1.0233 val_loss=0.8121 train_acc=0.4471 val_acc=0.7134 val_macro_auc=0.9177
# Epoch 41/50 -> train_loss=0.9896 val_loss=0.8142 train_acc=0.4153 val_acc=0.7134 val_macro_auc=0.9178
# Epoch 42/50 -> train_loss=1.0080 val_loss=0.8026 train_acc=0.4466 val_acc=0.7230 val_macro_auc=0.9208
# Epoch 43/50 -> train_loss=1.0067 val_loss=0.7895 train_acc=0.4694 val_acc=0.7305 val_macro_auc=0.9205
# Epoch 44/50 -> train_loss=0.9777 val_loss=0.7716 train_acc=0.4360 val_acc=0.7360 val_macro_auc=0.9208
# Epoch 45/50 -> train_loss=0.9285 val_loss=0.7465 train_acc=0.4544 val_acc=0.7497 val_macro_auc=0.9228
# Epoch 46/50 -> train_loss=1.0147 val_loss=0.7994 train_acc=0.4353 val_acc=0.7264 val_macro_auc=0.9205
# Epoch 47/50 -> train_loss=0.9870 val_loss=0.7736 train_acc=0.4979 val_acc=0.7360 val_macro_auc=0.9209
# Epoch 48/50 -> train_loss=0.9283 val_loss=0.7733 train_acc=0.4380 val_acc=0.7380 val_macro_auc=0.9205
# Epoch 49/50 -> train_loss=0.9634 val_loss=0.7921 train_acc=0.4507 val_acc=0.7244 val_macro_auc=0.9196
# Epoch 50/50 -> train_loss=0.9424 val_loss=0.7727 train_acc=0.4471 val_acc=0.7373 val_macro_auc=0.9213
# Saved training history to split_results/history_90-10.csv
# Saved loss curve to split_results/loss_curve_90-10.png
# Saved accuracy curve to split_results/acc_curve_90-10.png
# Saved ROC AUC curve to split_results/roc_auc_curve_90-10.png
#
# Classification report for split 90-10
#               precision    recall  f1-score      support
# CD             0.761364  0.783626  0.772334   171.000000
# HYP            0.246835  0.722222  0.367925    54.000000
# MI             0.705882  0.664032  0.684318   253.000000
# NORM           0.907407  0.756340  0.825015   907.000000
# STTC           0.629630  0.779167  0.696462   240.000000
# accuracy       0.747077  0.747077  0.747077     0.747077
# macro avg      0.650224  0.741077  0.669211  1625.000000
# weighted avg   0.797686  0.747077  0.763390  1625.000000
#
# ============================================================
# Running split: 80-20
# Sizes -> train: 11695 val: 1300 test: 3249
# Model params -> trainable: 292,357
# Epoch 01/50 -> train_loss=1.5802 val_loss=1.5243 train_acc=0.2465 val_acc=0.3408 val_macro_auc=0.7526
# Epoch 02/50 -> train_loss=1.4886 val_loss=1.5074 train_acc=0.2910 val_acc=0.2462 val_macro_auc=0.7767
# Epoch 03/50 -> train_loss=1.4050 val_loss=1.3991 train_acc=0.3319 val_acc=0.3631 val_macro_auc=0.8147
# Epoch 04/50 -> train_loss=1.3037 val_loss=1.2965 train_acc=0.3702 val_acc=0.4631 val_macro_auc=0.8440
# Epoch 05/50 -> train_loss=1.2547 val_loss=1.1465 train_acc=0.3597 val_acc=0.5954 val_macro_auc=0.8631
# Epoch 06/50 -> train_loss=1.2090 val_loss=1.1693 train_acc=0.3803 val_acc=0.5538 val_macro_auc=0.8724
# Epoch 07/50 -> train_loss=1.1516 val_loss=1.0337 train_acc=0.3767 val_acc=0.6315 val_macro_auc=0.8915
# Epoch 08/50 -> train_loss=1.1638 val_loss=1.0017 train_acc=0.3828 val_acc=0.6315 val_macro_auc=0.8919
# Epoch 09/50 -> train_loss=1.1243 val_loss=1.0000 train_acc=0.4191 val_acc=0.6477 val_macro_auc=0.9023
# Epoch 10/50 -> train_loss=1.1380 val_loss=1.0458 train_acc=0.3720 val_acc=0.6085 val_macro_auc=0.8983
# Epoch 11/50 -> train_loss=1.0434 val_loss=0.8217 train_acc=0.4857 val_acc=0.7085 val_macro_auc=0.9100
# Epoch 12/50 -> train_loss=1.0660 val_loss=0.9061 train_acc=0.4275 val_acc=0.6792 val_macro_auc=0.9019
# Epoch 13/50 -> train_loss=1.0992 val_loss=0.9070 train_acc=0.4375 val_acc=0.6685 val_macro_auc=0.9077
# Epoch 14/50 -> train_loss=1.0419 val_loss=0.9348 train_acc=0.4863 val_acc=0.6631 val_macro_auc=0.9112
# Epoch 15/50 -> train_loss=1.0264 val_loss=1.1019 train_acc=0.4638 val_acc=0.5800 val_macro_auc=0.8953
# Epoch 16/50 -> train_loss=1.0260 val_loss=0.8255 train_acc=0.4886 val_acc=0.7069 val_macro_auc=0.9142
# Epoch 17/50 -> train_loss=1.0381 val_loss=0.8455 train_acc=0.4790 val_acc=0.6969 val_macro_auc=0.9132
# Epoch 18/50 -> train_loss=1.0122 val_loss=0.7468 train_acc=0.4665 val_acc=0.7531 val_macro_auc=0.9213
# Epoch 19/50 -> train_loss=0.9814 val_loss=0.8759 train_acc=0.4262 val_acc=0.6854 val_macro_auc=0.9184
# Epoch 20/50 -> train_loss=0.9669 val_loss=0.8515 train_acc=0.4000 val_acc=0.6885 val_macro_auc=0.9142
# Epoch 21/50 -> train_loss=1.0309 val_loss=0.8952 train_acc=0.4658 val_acc=0.6738 val_macro_auc=0.9138
# Epoch 22/50 -> train_loss=1.0394 val_loss=0.8986 train_acc=0.4593 val_acc=0.6815 val_macro_auc=0.9114
# Epoch 23/50 -> train_loss=0.9493 val_loss=0.7809 train_acc=0.4243 val_acc=0.7354 val_macro_auc=0.9222
# Epoch 47/50 -> train_loss=0.9588 val_loss=0.8480 train_acc=0.4851 val_acc=0.6969 val_macro_auc=0.9198
# Epoch 48/50 -> train_loss=0.9731 val_loss=0.7792 train_acc=0.4906 val_acc=0.7354 val_macro_auc=0.9249
# Epoch 49/50 -> train_loss=0.9440 val_loss=0.8021 train_acc=0.5049 val_acc=0.7146 val_macro_auc=0.9228
# Epoch 50/50 -> train_loss=1.0604 val_loss=0.8556 train_acc=0.5398 val_acc=0.6938 val_macro_auc=0.9187
# Saved training history to split_results/history_80-20.csv
# Saved loss curve to split_results/loss_curve_80-20.png
# Saved accuracy curve to split_results/acc_curve_80-20.png
# Saved ROC AUC curve to split_results/roc_auc_curve_80-20.png
#
# Classification report for split 80-20
#               precision    recall  f1-score      support
# CD             0.702290  0.807018  0.751020   342.000000
# HYP            0.250696  0.841121  0.386266   107.000000
# MI             0.743243  0.543478  0.627854   506.000000
# NORM           0.894335  0.774531  0.830133  1814.000000
# STTC           0.640288  0.741667  0.687259   480.000000
# accuracy       0.739304  0.739304  0.739304     0.739304
# macro avg      0.646170  0.741563  0.656506  3249.000000
# weighted avg   0.791859  0.739304  0.754576  3249.000000
#
# ============================================================
# Running split: 70-30
# Sizes -> train: 10233 val: 1137 test: 4874
# Model params -> trainable: 292,357
# Epoch 01/50 -> train_loss=1.5760 val_loss=1.5494 train_acc=0.2472 val_acc=0.2630 val_macro_auc=0.7599
# Epoch 02/50 -> train_loss=1.4899 val_loss=1.4851 train_acc=0.2728 val_acc=0.3369 val_macro_auc=0.7848
# Epoch 03/50 -> train_loss=1.4112 val_loss=1.3873 train_acc=0.3148 val_acc=0.4512 val_macro_auc=0.8163
# Epoch 04/50 -> train_loss=1.3491 val_loss=1.2792 train_acc=0.3710 val_acc=0.5242 val_macro_auc=0.8315
# Epoch 05/50 -> train_loss=1.2952 val_loss=1.2376 train_acc=0.3300 val_acc=0.5198 val_macro_auc=0.8464
# Epoch 06/50 -> train_loss=1.2102 val_loss=1.1539 train_acc=0.4190 val_acc=0.5690 val_macro_auc=0.8549
# Epoch 07/50 -> train_loss=1.1940 val_loss=1.1188 train_acc=0.4286 val_acc=0.5945 val_macro_auc=0.8613
# Epoch 08/50 -> train_loss=1.1484 val_loss=1.1776 train_acc=0.4286 val_acc=0.5312 val_macro_auc=0.8652
# Epoch 09/50 -> train_loss=1.1462 val_loss=1.0112 train_acc=0.4229 val_acc=0.6403 val_macro_auc=0.8726
# Epoch 10/50 -> train_loss=1.1116 val_loss=1.0837 train_acc=0.4210 val_acc=0.6016 val_macro_auc=0.8728
# Epoch 11/50 -> train_loss=1.0758 val_loss=1.1033 train_acc=0.4146 val_acc=0.6060 val_macro_auc=0.8709
# Epoch 12/50 -> train_loss=1.1010 val_loss=0.8654 train_acc=0.3631 val_acc=0.6983 val_macro_auc=0.8923
# Epoch 13/50 -> train_loss=1.0530 val_loss=0.9582 train_acc=0.4918 val_acc=0.6614 val_macro_auc=0.8889
# Epoch 14/50 -> train_loss=1.0372 val_loss=0.9226 train_acc=0.4585 val_acc=0.6807 val_macro_auc=0.8870
# Epoch 38/50 -> train_loss=0.9665 val_loss=0.8483 train_acc=0.4323 val_acc=0.6939 val_macro_auc=0.9078
# Epoch 39/50 -> train_loss=0.8913 val_loss=0.8097 train_acc=0.3938 val_acc=0.7168 val_macro_auc=0.9101
# Epoch 40/50 -> train_loss=0.9424 val_loss=0.8277 train_acc=0.4417 val_acc=0.7080 val_macro_auc=0.9091
# Epoch 41/50 -> train_loss=1.0233 val_loss=0.8259 train_acc=0.4505 val_acc=0.7098 val_macro_auc=0.9092
# Epoch 42/50 -> train_loss=0.9338 val_loss=0.8337 train_acc=0.5059 val_acc=0.7045 val_macro_auc=0.9095
# Epoch 43/50 -> train_loss=0.9637 val_loss=0.7982 train_acc=0.5553 val_acc=0.7221 val_macro_auc=0.9120
# Epoch 44/50 -> train_loss=0.9830 val_loss=0.8315 train_acc=0.5164 val_acc=0.7054 val_macro_auc=0.9098
# Epoch 45/50 -> train_loss=0.9208 val_loss=0.8286 train_acc=0.4357 val_acc=0.7054 val_macro_auc=0.9097
# Epoch 46/50 -> train_loss=0.9149 val_loss=0.8349 train_acc=0.4369 val_acc=0.7045 val_macro_auc=0.9091
# Epoch 47/50 -> train_loss=0.9813 val_loss=0.8192 train_acc=0.4973 val_acc=0.7098 val_macro_auc=0.9102
# Epoch 48/50 -> train_loss=0.9178 val_loss=0.8280 train_acc=0.4137 val_acc=0.7062 val_macro_auc=0.9099
# Epoch 49/50 -> train_loss=0.9901 val_loss=0.8500 train_acc=0.4512 val_acc=0.6992 val_macro_auc=0.9083
# Epoch 50/50 -> train_loss=0.9391 val_loss=0.8146 train_acc=0.5401 val_acc=0.7133 val_macro_auc=0.9105
# Saved training history to split_results/history_70-30.csv
# Saved loss curve to split_results/loss_curve_70-30.png
# Saved accuracy curve to split_results/acc_curve_70-30.png
# Saved ROC AUC curve to split_results/roc_auc_curve_70-30.png
#
# Classification report for split 70-30
#               precision    recall  f1-score      support
# CD             0.821586  0.728516  0.772257   512.000000
# HYP            0.318750  0.633540  0.424116   161.000000
# MI             0.682471  0.625000  0.652473   760.000000
# NORM           0.890857  0.794928  0.840163  2721.000000
# STTC           0.591189  0.801389  0.680425   720.000000
# accuracy       0.757078  0.757078  0.757078     0.757078
# macro avg      0.660970  0.716675  0.673887  4874.000000
# weighted avg   0.787921  0.757078  0.766423  4874.000000
#
# ============================================================
# Running split: 60-40
# Sizes -> train: 8771 val: 975 test: 6498
# Model params -> trainable: 292,357
# Epoch 01/50 -> train_loss=1.6062 val_loss=1.5486 train_acc=0.2233 val_acc=0.1764 val_macro_auc=0.6949
# Epoch 02/50 -> train_loss=1.5365 val_loss=1.5382 train_acc=0.2628 val_acc=0.2851 val_macro_auc=0.7401
# Epoch 03/50 -> train_loss=1.4691 val_loss=1.5020 train_acc=0.2902 val_acc=0.3518 val_macro_auc=0.7683
# Epoch 04/50 -> train_loss=1.3890 val_loss=1.3820 train_acc=0.3526 val_acc=0.4256 val_macro_auc=0.7984
# Epoch 05/50 -> train_loss=1.3506 val_loss=1.3036 train_acc=0.3393 val_acc=0.4841 val_macro_auc=0.8249
# Epoch 30/50 -> train_loss=0.9727 val_loss=0.8047 train_acc=0.3629 val_acc=0.6954 val_macro_auc=0.9135
# Epoch 31/50 -> train_loss=1.0171 val_loss=0.8607 train_acc=0.5419 val_acc=0.6841 val_macro_auc=0.9108
# Epoch 32/50 -> train_loss=1.0679 val_loss=0.8474 train_acc=0.4286 val_acc=0.6718 val_macro_auc=0.9120
# Epoch 33/50 -> train_loss=1.0178 val_loss=0.8587 train_acc=0.4588 val_acc=0.6718 val_macro_auc=0.9108
# Epoch 34/50 -> train_loss=1.0440 val_loss=0.8235 train_acc=0.4908 val_acc=0.6913 val_macro_auc=0.9136
# Epoch 35/50 -> train_loss=1.0646 val_loss=0.8815 train_acc=0.5097 val_acc=0.6687 val_macro_auc=0.9096
# Epoch 36/50 -> train_loss=0.9772 val_loss=0.8304 train_acc=0.4331 val_acc=0.6872 val_macro_auc=0.9153
# Epoch 37/50 -> train_loss=1.0608 val_loss=0.8787 train_acc=0.4425 val_acc=0.6718 val_macro_auc=0.9103
# Epoch 38/50 -> train_loss=1.0517 val_loss=0.8611 train_acc=0.4049 val_acc=0.6769 val_macro_auc=0.9116
# Epoch 39/50 -> train_loss=1.0489 val_loss=0.8425 train_acc=0.4086 val_acc=0.6779 val_macro_auc=0.9125
# Epoch 40/50 -> train_loss=1.0090 val_loss=0.8292 train_acc=0.4617 val_acc=0.6831 val_macro_auc=0.9137
# Epoch 41/50 -> train_loss=0.9512 val_loss=0.8114 train_acc=0.4361 val_acc=0.6923 val_macro_auc=0.9152
# Epoch 42/50 -> train_loss=1.0004 val_loss=0.8404 train_acc=0.4109 val_acc=0.6769 val_macro_auc=0.9130
# Epoch 43/50 -> train_loss=1.0363 val_loss=0.8496 train_acc=0.4485 val_acc=0.6749 val_macro_auc=0.9129
# Epoch 44/50 -> train_loss=1.0479 val_loss=0.8564 train_acc=0.4066 val_acc=0.6769 val_macro_auc=0.9132
# Epoch 45/50 -> train_loss=1.0316 val_loss=0.8506 train_acc=0.4302 val_acc=0.6779 val_macro_auc=0.9136
# Epoch 46/50 -> train_loss=0.9839 val_loss=0.8258 train_acc=0.4367 val_acc=0.6821 val_macro_auc=0.9140
# Epoch 47/50 -> train_loss=1.0180 val_loss=0.8420 train_acc=0.4636 val_acc=0.6831 val_macro_auc=0.9126
# Epoch 48/50 -> train_loss=0.9763 val_loss=0.8018 train_acc=0.4578 val_acc=0.6882 val_macro_auc=0.9159
# Epoch 49/50 -> train_loss=1.0314 val_loss=0.8440 train_acc=0.4418 val_acc=0.6759 val_macro_auc=0.9129
# Epoch 50/50 -> train_loss=1.0150 val_loss=0.8600 train_acc=0.4197 val_acc=0.6738 val_macro_auc=0.9127
# Saved training history to split_results/history_60-40.csv
# Saved loss curve to split_results/loss_curve_60-40.png
# Saved accuracy curve to split_results/acc_curve_60-40.png
# Saved ROC AUC curve to split_results/roc_auc_curve_60-40.png
#
# Classification report for split 60-40
#               precision    recall  f1-score      support
# CD             0.694696  0.786237  0.737637   683.000000
# HYP            0.260870  0.728972  0.384236   214.000000
# MI             0.610460  0.668312  0.638077  1013.000000
# NORM           0.900167  0.743109  0.814133  3628.000000
# STTC           0.647116  0.689583  0.667675   960.000000
# accuracy       0.727608  0.727608  0.727608     0.727608
# macro avg      0.622662  0.723243  0.648352  6498.000000
# weighted avg   0.774967  0.727608  0.742851  6498.000000
#
# ============================================================
# Running split: 50-50
# Sizes -> train: 7309 val: 813 test: 8122
# Model params -> trainable: 292,357
# Epoch 01/50 -> train_loss=1.5942 val_loss=1.5444 train_acc=0.2233 val_acc=0.1808 val_macro_auc=0.6743
# Epoch 02/50 -> train_loss=1.5330 val_loss=1.5027 train_acc=0.2558 val_acc=0.3542 val_macro_auc=0.7309
# Epoch 03/50 -> train_loss=1.4665 val_loss=1.4605 train_acc=0.2773 val_acc=0.3247 val_macro_auc=0.7577
# Epoch 04/50 -> train_loss=1.4211 val_loss=1.4366 train_acc=0.3032 val_acc=0.3407 val_macro_auc=0.7780
# Epoch 05/50 -> train_loss=1.3706 val_loss=1.3559 train_acc=0.3307 val_acc=0.4047 val_macro_auc=0.8007
# Epoch 06/50 -> train_loss=1.3196 val_loss=1.4242 train_acc=0.3578 val_acc=0.3432 val_macro_auc=0.7977
# Epoch 07/50 -> train_loss=1.3121 val_loss=1.2539 train_acc=0.3388 val_acc=0.4637 val_macro_auc=0.8283
# Epoch 08/50 -> train_loss=1.2369 val_loss=1.3096 train_acc=0.3593 val_acc=0.4096 val_macro_auc=0.8227
# Epoch 09/50 -> train_loss=1.2638 val_loss=1.1151 train_acc=0.3656 val_acc=0.5756 val_macro_auc=0.8499
# Epoch 10/50 -> train_loss=1.1690 val_loss=1.1224 train_acc=0.3474 val_acc=0.5855 val_macro_auc=0.8533
# Epoch 11/50 -> train_loss=1.1989 val_loss=1.1323 train_acc=0.3708 val_acc=0.5510 val_macro_auc=0.8605
# Epoch 12/50 -> train_loss=1.1239 val_loss=0.9912 train_acc=0.3697 val_acc=0.6408 val_macro_auc=0.8726
# Epoch 13/50 -> train_loss=1.1422 val_loss=0.9573 train_acc=0.3731 val_acc=0.6581 val_macro_auc=0.8789
# Epoch 14/50 -> train_loss=1.1336 val_loss=0.8826 train_acc=0.4490 val_acc=0.6888 val_macro_auc=0.8855
# Epoch 15/50 -> train_loss=1.1078 val_loss=1.0648 train_acc=0.4344 val_acc=0.5916 val_macro_auc=0.8740
# Epoch 16/50 -> train_loss=1.0841 val_loss=0.8053 train_acc=0.4157 val_acc=0.7306 val_macro_auc=0.8934
# Epoch 17/50 -> train_loss=1.0755 val_loss=0.9674 train_acc=0.4178 val_acc=0.6212 val_macro_auc=0.8889
# Epoch 18/50 -> train_loss=1.0149 val_loss=0.8746 train_acc=0.4627 val_acc=0.6740 val_macro_auc=0.8873
# Epoch 19/50 -> train_loss=1.1351 val_loss=0.9057 train_acc=0.4077 val_acc=0.6617 val_macro_auc=0.8954
# Epoch 20/50 -> train_loss=1.0745 val_loss=1.0752 train_acc=0.3909 val_acc=0.5658 val_macro_auc=0.8816
# Epoch 45/50 -> train_loss=1.0007 val_loss=0.8934 train_acc=0.5002 val_acc=0.6531 val_macro_auc=0.8974
# Epoch 46/50 -> train_loss=1.0309 val_loss=0.8385 train_acc=0.5455 val_acc=0.6765 val_macro_auc=0.9023
# Epoch 47/50 -> train_loss=1.0162 val_loss=0.8964 train_acc=0.5086 val_acc=0.6544 val_macro_auc=0.8974
# Epoch 48/50 -> train_loss=0.9742 val_loss=0.8288 train_acc=0.4237 val_acc=0.6839 val_macro_auc=0.9028
# Epoch 49/50 -> train_loss=0.9897 val_loss=0.8630 train_acc=0.4572 val_acc=0.6605 val_macro_auc=0.9011
# Epoch 50/50 -> train_loss=0.9983 val_loss=0.8697 train_acc=0.4878 val_acc=0.6581 val_macro_auc=0.8999
# Saved training history to split_results/history_50-50.csv
# Saved loss curve to split_results/loss_curve_50-50.png
# Saved accuracy curve to split_results/acc_curve_50-50.png
# Saved ROC AUC curve to split_results/roc_auc_curve_50-50.png
#
# Classification report for split 50-50
#               precision    recall  f1-score     support
# CD             0.668072  0.742389  0.703272   854.00000
# HYP            0.300325  0.690299  0.418552   268.00000
# MI             0.698182  0.454976  0.550933  1266.00000
# NORM           0.831119  0.855315  0.843043  4534.00000
# STTC           0.686679  0.610000  0.646072  1200.00000
# accuracy       0.739350  0.739350  0.739350     0.73935
# macro avg      0.636875  0.670596  0.632375  8122.00000
# weighted avg   0.754399  0.739350  0.739706  8122.00000
#
# ============================================================
# Running split: 40-60
# Sizes -> train: 5847 val: 650 test: 9747
# Model params -> trainable: 292,357
# Epoch 01/50 -> train_loss=1.5962 val_loss=1.5678 train_acc=0.2213 val_acc=0.1554 val_macro_auc=0.6961
# Epoch 02/50 -> train_loss=1.5478 val_loss=1.4985 train_acc=0.2543 val_acc=0.5062 val_macro_auc=0.7426
# Epoch 03/50 -> train_loss=1.5023 val_loss=1.4959 train_acc=0.2711 val_acc=0.3738 val_macro_auc=0.7416
# Epoch 04/50 -> train_loss=1.4572 val_loss=1.4594 train_acc=0.3109 val_acc=0.4046 val_macro_auc=0.7630
# Epoch 05/50 -> train_loss=1.4156 val_loss=1.4055 train_acc=0.3344 val_acc=0.4338 val_macro_auc=0.7913
# Epoch 06/50 -> train_loss=1.3648 val_loss=1.3563 train_acc=0.3446 val_acc=0.4400 val_macro_auc=0.8044
# Epoch 07/50 -> train_loss=1.3154 val_loss=1.2503 train_acc=0.3944 val_acc=0.5354 val_macro_auc=0.8252
# Epoch 08/50 -> train_loss=1.2751 val_loss=1.2717 train_acc=0.3728 val_acc=0.4908 val_macro_auc=0.8297
# Epoch 09/50 -> train_loss=1.2138 val_loss=1.1744 train_acc=0.3887 val_acc=0.5477 val_macro_auc=0.8511
# Epoch 10/50 -> train_loss=1.2164 val_loss=1.1606 train_acc=0.3747 val_acc=0.5708 val_macro_auc=0.8543
# Epoch 11/50 -> train_loss=1.1810 val_loss=1.0772 train_acc=0.3520 val_acc=0.5938 val_macro_auc=0.8631
# Epoch 12/50 -> train_loss=1.1545 val_loss=1.0344 train_acc=0.4123 val_acc=0.6415 val_macro_auc=0.8824
# Epoch 36/50 -> train_loss=0.9607 val_loss=0.8468 train_acc=0.4219 val_acc=0.6985 val_macro_auc=0.9046
# Epoch 37/50 -> train_loss=1.0271 val_loss=0.9375 train_acc=0.4125 val_acc=0.6554 val_macro_auc=0.8946
# Epoch 38/50 -> train_loss=1.0286 val_loss=0.9041 train_acc=0.4717 val_acc=0.6646 val_macro_auc=0.8968
# Epoch 39/50 -> train_loss=1.0345 val_loss=0.9296 train_acc=0.4192 val_acc=0.6600 val_macro_auc=0.8988
# Epoch 40/50 -> train_loss=1.0455 val_loss=0.9294 train_acc=0.5242 val_acc=0.6585 val_macro_auc=0.8939
# Epoch 41/50 -> train_loss=1.0104 val_loss=0.8610 train_acc=0.4780 val_acc=0.6908 val_macro_auc=0.9032
# Epoch 42/50 -> train_loss=0.9446 val_loss=0.9011 train_acc=0.5206 val_acc=0.6631 val_macro_auc=0.9011
# Epoch 43/50 -> train_loss=1.0377 val_loss=0.9486 train_acc=0.4235 val_acc=0.6492 val_macro_auc=0.8972
# Epoch 44/50 -> train_loss=0.9318 val_loss=0.8585 train_acc=0.4476 val_acc=0.6769 val_macro_auc=0.9040
# Epoch 45/50 -> train_loss=1.0257 val_loss=0.8895 train_acc=0.3865 val_acc=0.6677 val_macro_auc=0.9015
# Epoch 46/50 -> train_loss=0.9981 val_loss=0.9227 train_acc=0.4761 val_acc=0.6631 val_macro_auc=0.8991
# Epoch 47/50 -> train_loss=0.9645 val_loss=0.8733 train_acc=0.4156 val_acc=0.6708 val_macro_auc=0.9029
# Epoch 48/50 -> train_loss=0.9205 val_loss=0.8638 train_acc=0.4888 val_acc=0.6785 val_macro_auc=0.9032
# Epoch 49/50 -> train_loss=0.9694 val_loss=0.8713 train_acc=0.4214 val_acc=0.6754 val_macro_auc=0.9033
# Epoch 50/50 -> train_loss=0.9789 val_loss=0.8720 train_acc=0.4454 val_acc=0.6692 val_macro_auc=0.9012
# Saved training history to split_results/history_40-60.csv
# Saved loss curve to split_results/loss_curve_40-60.png
# Saved accuracy curve to split_results/acc_curve_40-60.png
# Saved ROC AUC curve to split_results/roc_auc_curve_40-60.png
#
# Classification report for split 40-60
#               precision    recall  f1-score      support
# CD             0.623267  0.789268  0.696513  1025.000000
# HYP            0.229853  0.781931  0.355272   321.000000
# MI             0.623274  0.624095  0.623684  1519.000000
# NORM           0.884689  0.761301  0.818370  5442.000000
# STTC           0.717259  0.574306  0.637871  1440.000000
# accuracy       0.715913  0.715913  0.715913     0.715913
# macro avg      0.615669  0.706180  0.626342  9747.000000
# weighted avg   0.770157  0.715913  0.733298  9747.000000
#
# ============================================================
# Running split: 30-70
# Sizes -> train: 4385 val: 488 test: 11371
# Model params -> trainable: 292,357
# Epoch 01/50 -> train_loss=1.6085 val_loss=1.5983 train_acc=0.2130 val_acc=0.1455 val_macro_auc=0.6980
# Epoch 02/50 -> train_loss=1.5683 val_loss=1.5772 train_acc=0.2292 val_acc=0.2111 val_macro_auc=0.7399
# Epoch 03/50 -> train_loss=1.5285 val_loss=1.5600 train_acc=0.2625 val_acc=0.2131 val_macro_auc=0.7672
# Epoch 04/50 -> train_loss=1.5151 val_loss=1.5107 train_acc=0.2582 val_acc=0.2541 val_macro_auc=0.7924
# Epoch 05/50 -> train_loss=1.4740 val_loss=1.4841 train_acc=0.2924 val_acc=0.2869 val_macro_auc=0.8113
# Epoch 06/50 -> train_loss=1.4421 val_loss=1.4774 train_acc=0.3117 val_acc=0.2971 val_macro_auc=0.8170
# Epoch 07/50 -> train_loss=1.3999 val_loss=1.4672 train_acc=0.3168 val_acc=0.2643 val_macro_auc=0.8177
# Epoch 08/50 -> train_loss=1.3412 val_loss=1.3734 train_acc=0.3156 val_acc=0.3791 val_macro_auc=0.8332
# Epoch 09/50 -> train_loss=1.3263 val_loss=1.3667 train_acc=0.3644 val_acc=0.3709 val_macro_auc=0.8352
# Epoch 10/50 -> train_loss=1.3017 val_loss=1.4136 train_acc=0.3318 val_acc=0.3422 val_macro_auc=0.8330
# Epoch 11/50 -> train_loss=1.2489 val_loss=1.4071 train_acc=0.3665 val_acc=0.3566 val_macro_auc=0.8377
# Epoch 12/50 -> train_loss=1.2250 val_loss=1.2582 train_acc=0.3496 val_acc=0.4426 val_macro_auc=0.8571
# Epoch 13/50 -> train_loss=1.2137 val_loss=1.2741 train_acc=0.4495 val_acc=0.4877 val_macro_auc=0.8617
# Epoch 14/50 -> train_loss=1.1807 val_loss=1.2101 train_acc=0.3790 val_acc=0.5246 val_macro_auc=0.8661
# Epoch 15/50 -> train_loss=1.1833 val_loss=1.1987 train_acc=0.3834 val_acc=0.5369 val_macro_auc=0.8705
# Epoch 16/50 -> train_loss=1.1678 val_loss=1.1138 train_acc=0.4374 val_acc=0.5635 val_macro_auc=0.8793
# Epoch 17/50 -> train_loss=1.1666 val_loss=1.1169 train_acc=0.4908 val_acc=0.6004 val_macro_auc=0.8817
# Epoch 18/50 -> train_loss=1.1562 val_loss=1.2898 train_acc=0.5341 val_acc=0.5082 val_macro_auc=0.8716
# Epoch 19/50 -> train_loss=1.0989 val_loss=0.9731 train_acc=0.3991 val_acc=0.6865 val_macro_auc=0.8852
# Epoch 20/50 -> train_loss=1.1317 val_loss=0.9609 train_acc=0.4449 val_acc=0.7029 val_macro_auc=0.8915
# Epoch 21/50 -> train_loss=1.1216 val_loss=1.0296 train_acc=0.4281 val_acc=0.6189 val_macro_auc=0.8914
# Epoch 22/50 -> train_loss=1.0507 val_loss=0.9779 train_acc=0.3692 val_acc=0.6434 val_macro_auc=0.8847
# Epoch 23/50 -> train_loss=0.9985 val_loss=1.0004 train_acc=0.3428 val_acc=0.6455 val_macro_auc=0.8919
# Epoch 24/50 -> train_loss=1.0340 val_loss=0.9823 train_acc=0.3658 val_acc=0.6475 val_macro_auc=0.8961
# Epoch 25/50 -> train_loss=1.0705 val_loss=1.1492 train_acc=0.4620 val_acc=0.5820 val_macro_auc=0.8889
# Epoch 26/50 -> train_loss=1.0392 val_loss=0.9478 train_acc=0.3777 val_acc=0.6660 val_macro_auc=0.8999
# Saved training history to split_results/history_30-70.csv
# Saved loss curve to split_results/loss_curve_30-70.png
# Saved accuracy curve to split_results/acc_curve_30-70.png
# Saved ROC AUC curve to split_results/roc_auc_curve_30-70.png
#
# Classification report for split 30-70
#               precision    recall  f1-score       support
# CD             0.604326  0.794314  0.686416   1196.000000
# HYP            0.212568  0.730667  0.329327    375.000000
# MI             0.577320  0.632054  0.603448   1772.000000
# NORM           0.902156  0.685570  0.779091   6348.000000
# STTC           0.626575  0.651190  0.638646   1680.000000
# accuracy       0.685076  0.685076  0.685076      0.685076
# macro avg      0.584589  0.698759  0.607386  11371.000000
# weighted avg   0.756752  0.685076  0.706389  11371.000000
#
# ============================================================
# Running split: 19-80
# Sizes -> train: 2923 val: 325 test: 12996
# Model params -> trainable: 292,357
# Epoch 01/50 -> train_loss=1.6122 val_loss=1.6144 train_acc=0.2036 val_acc=0.1477 val_macro_auc=0.6737
# Epoch 02/50 -> train_loss=1.5849 val_loss=1.5814 train_acc=0.2296 val_acc=0.1477 val_macro_auc=0.7091
# Epoch 03/50 -> train_loss=1.5667 val_loss=1.5491 train_acc=0.2350 val_acc=0.1785 val_macro_auc=0.7328
# Epoch 04/50 -> train_loss=1.5461 val_loss=1.5238 train_acc=0.2374 val_acc=0.3569 val_macro_auc=0.7459
# Epoch 05/50 -> train_loss=1.5122 val_loss=1.5084 train_acc=0.3076 val_acc=0.3477 val_macro_auc=0.7545
# Epoch 06/50 -> train_loss=1.4985 val_loss=1.5270 train_acc=0.2826 val_acc=0.3600 val_macro_auc=0.7608
# Epoch 07/50 -> train_loss=1.4630 val_loss=1.5360 train_acc=0.2648 val_acc=0.3692 val_macro_auc=0.7708
# Epoch 08/50 -> train_loss=1.4375 val_loss=1.4789 train_acc=0.3671 val_acc=0.3785 val_macro_auc=0.7885
# Epoch 09/50 -> train_loss=1.3838 val_loss=1.3964 train_acc=0.3291 val_acc=0.4585 val_macro_auc=0.8022
# Epoch 10/50 -> train_loss=1.3944 val_loss=1.4113 train_acc=0.3678 val_acc=0.4092 val_macro_auc=0.8023
# Epoch 11/50 -> train_loss=1.3440 val_loss=1.3949 train_acc=0.3934 val_acc=0.4246 val_macro_auc=0.8112
# Epoch 12/50 -> train_loss=1.3112 val_loss=1.3753 train_acc=0.3999 val_acc=0.4338 val_macro_auc=0.8191
# Epoch 13/50 -> train_loss=1.3004 val_loss=1.3280 train_acc=0.3257 val_acc=0.5415 val_macro_auc=0.8270
# Epoch 14/50 -> train_loss=1.2568 val_loss=1.2382 train_acc=0.3832 val_acc=0.5600 val_macro_auc=0.8399
# Epoch 15/50 -> train_loss=1.2585 val_loss=1.4107 train_acc=0.3531 val_acc=0.3815 val_macro_auc=0.8199
# Epoch 16/50 -> train_loss=1.2721 val_loss=1.2264 train_acc=0.3418 val_acc=0.5262 val_macro_auc=0.8495
# Epoch 17/50 -> train_loss=1.2468 val_loss=1.3574 train_acc=0.4051 val_acc=0.4338 val_macro_auc=0.8378
# Epoch 18/50 -> train_loss=1.1880 val_loss=1.2475 train_acc=0.3171 val_acc=0.5754 val_macro_auc=0.8484
# Epoch 19/50 -> train_loss=1.1764 val_loss=1.2551 train_acc=0.3267 val_acc=0.5108 val_macro_auc=0.8466
# Epoch 20/50 -> train_loss=1.1995 val_loss=1.2021 train_acc=0.3579 val_acc=0.5538 val_macro_auc=0.8537
# Epoch 21/50 -> train_loss=1.0871 val_loss=1.0503 train_acc=0.3695 val_acc=0.6677 val_macro_auc=0.8636
# Epoch 22/50 -> train_loss=1.1494 val_loss=0.9728 train_acc=0.4081 val_acc=0.6923 val_macro_auc=0.8688
# Epoch 23/50 -> train_loss=1.1603 val_loss=1.1645 train_acc=0.4660 val_acc=0.5600 val_macro_auc=0.8499
# Epoch 24/50 -> train_loss=1.1591 val_loss=1.0395 train_acc=0.5009 val_acc=0.6092 val_macro_auc=0.8717
# Epoch 25/50 -> train_loss=1.1459 val_loss=1.0128 train_acc=0.4642 val_acc=0.6738 val_macro_auc=0.8728
# Epoch 26/50 -> train_loss=1.1024 val_loss=1.0298 train_acc=0.4742 val_acc=0.6400 val_macro_auc=0.8716
# Epoch 27/50 -> train_loss=1.0734 val_loss=0.9927 train_acc=0.4057 val_acc=0.6677 val_macro_auc=0.8765
# Epoch 28/50 -> train_loss=1.0813 val_loss=0.9812 train_acc=0.3948 val_acc=0.6677 val_macro_auc=0.8698
# Epoch 29/50 -> train_loss=1.1333 val_loss=1.0512 train_acc=0.4348 val_acc=0.6431 val_macro_auc=0.8673
# Epoch 30/50 -> train_loss=1.0145 val_loss=0.9650 train_acc=0.3760 val_acc=0.6862 val_macro_auc=0.8792
# Epoch 31/50 -> train_loss=1.0635 val_loss=0.9992 train_acc=0.4519 val_acc=0.6369 val_macro_auc=0.8781
# Epoch 32/50 -> train_loss=1.0772 val_loss=1.0458 train_acc=0.4530 val_acc=0.6123 val_macro_auc=0.8678
# Epoch 33/50 -> train_loss=1.0163 val_loss=0.9322 train_acc=0.4564 val_acc=0.6862 val_macro_auc=0.8747
# Epoch 34/50 -> train_loss=1.1381 val_loss=0.9902 train_acc=0.4516 val_acc=0.6400 val_macro_auc=0.8701
# Epoch 35/50 -> train_loss=0.9737 val_loss=0.9460 train_acc=0.4701 val_acc=0.6800 val_macro_auc=0.8771
# Epoch 36/50 -> train_loss=1.0024 val_loss=1.0503 train_acc=0.4492 val_acc=0.6185 val_macro_auc=0.8670
# Epoch 37/50 -> train_loss=1.0083 val_loss=0.9646 train_acc=0.4379 val_acc=0.6554 val_macro_auc=0.8760
# Epoch 38/50 -> train_loss=0.9497 val_loss=0.9289 train_acc=0.3534 val_acc=0.6708 val_macro_auc=0.8773
# Epoch 39/50 -> train_loss=1.1002 val_loss=0.9927 train_acc=0.4071 val_acc=0.6615 val_macro_auc=0.8710
# Epoch 40/50 -> train_loss=1.0070 val_loss=0.9267 train_acc=0.3722 val_acc=0.7169 val_macro_auc=0.8758
# Epoch 41/50 -> train_loss=0.9814 val_loss=0.8990 train_acc=0.5850 val_acc=0.7108 val_macro_auc=0.8772
# Epoch 42/50 -> train_loss=0.9623 val_loss=0.9699 train_acc=0.5713 val_acc=0.6738 val_macro_auc=0.8728
# Epoch 43/50 -> train_loss=1.0710 val_loss=0.9776 train_acc=0.4796 val_acc=0.6492 val_macro_auc=0.8712
# Epoch 44/50 -> train_loss=1.0412 val_loss=0.9407 train_acc=0.5067 val_acc=0.6615 val_macro_auc=0.8760
# Epoch 45/50 -> train_loss=0.9466 val_loss=0.9724 train_acc=0.4920 val_acc=0.6769 val_macro_auc=0.8717
# Epoch 46/50 -> train_loss=1.0609 val_loss=0.8932 train_acc=0.3298 val_acc=0.7046 val_macro_auc=0.8764
# Epoch 47/50 -> train_loss=1.0490 val_loss=0.9536 train_acc=0.3866 val_acc=0.6708 val_macro_auc=0.8750
# Epoch 48/50 -> train_loss=1.0301 val_loss=0.9459 train_acc=0.4687 val_acc=0.6892 val_macro_auc=0.8755
# Epoch 49/50 -> train_loss=1.0370 val_loss=0.9447 train_acc=0.4396 val_acc=0.6831 val_macro_auc=0.8751
# Epoch 50/50 -> train_loss=0.8691 val_loss=0.9227 train_acc=0.5207 val_acc=0.6831 val_macro_auc=0.8803
# Saved training history to split_results/history_19-80.csv
# Saved loss curve to split_results/loss_curve_19-80.png
# Saved accuracy curve to split_results/acc_curve_19-80.png
# Saved ROC AUC curve to split_results/roc_auc_curve_19-80.png
#
# Classification report for split 19-80
#               precision    recall  f1-score       support
# CD             0.682507  0.725476  0.703336   1366.000000
# HYP            0.203187  0.714953  0.316443    428.000000
# MI             0.644024  0.486673  0.554400   2026.000000
# NORM           0.862545  0.732497  0.792219   7256.000000
# STTC           0.565032  0.690104  0.621336   1920.000000
# accuracy       0.686596  0.686596  0.686596      0.686596
# macro avg      0.591459  0.669941  0.597547  12996.000000
# weighted avg   0.743886  0.686596  0.704888  12996.000000
#
# ============================================================
# Running split: 9-90
# Sizes -> train: 1461 val: 163 test: 14620
# Model params -> trainable: 292,357
# Epoch 01/50 -> train_loss=1.6385 val_loss=1.6057 train_acc=0.1923 val_acc=0.1595 val_macro_auc=0.7030
# Epoch 02/50 -> train_loss=1.6138 val_loss=1.6011 train_acc=0.2190 val_acc=0.1595 val_macro_auc=0.7282
# Epoch 03/50 -> train_loss=1.6028 val_loss=1.5939 train_acc=0.2355 val_acc=0.1718 val_macro_auc=0.7412
# Epoch 04/50 -> train_loss=1.5878 val_loss=1.5833 train_acc=0.2293 val_acc=0.1779 val_macro_auc=0.7460
# Epoch 05/50 -> train_loss=1.5648 val_loss=1.5713 train_acc=0.2485 val_acc=0.1963 val_macro_auc=0.7655
# Epoch 06/50 -> train_loss=1.5524 val_loss=1.5473 train_acc=0.2163 val_acc=0.3252 val_macro_auc=0.7880
# Epoch 07/50 -> train_loss=1.5574 val_loss=1.5198 train_acc=0.2361 val_acc=0.5276 val_macro_auc=0.7991
# Epoch 08/50 -> train_loss=1.5266 val_loss=1.5048 train_acc=0.2991 val_acc=0.5521 val_macro_auc=0.7983
# Epoch 09/50 -> train_loss=1.5336 val_loss=1.5002 train_acc=0.2560 val_acc=0.4601 val_macro_auc=0.7980
# Epoch 10/50 -> train_loss=1.4919 val_loss=1.4965 train_acc=0.2738 val_acc=0.4110 val_macro_auc=0.8035
# Epoch 11/50 -> train_loss=1.4780 val_loss=1.4887 train_acc=0.3053 val_acc=0.4049 val_macro_auc=0.8078
# Epoch 12/50 -> train_loss=1.4757 val_loss=1.4827 train_acc=0.2498 val_acc=0.3926 val_macro_auc=0.8090
# Epoch 13/50 -> train_loss=1.4617 val_loss=1.4864 train_acc=0.2861 val_acc=0.3558 val_macro_auc=0.8060
# Epoch 14/50 -> train_loss=1.4487 val_loss=1.4553 train_acc=0.3552 val_acc=0.4172 val_macro_auc=0.8145
# Epoch 15/50 -> train_loss=1.4527 val_loss=1.4355 train_acc=0.3231 val_acc=0.4110 val_macro_auc=0.8163
# Epoch 16/50 -> train_loss=1.4043 val_loss=1.4138 train_acc=0.2841 val_acc=0.4356 val_macro_auc=0.8279
# Epoch 17/50 -> train_loss=1.3899 val_loss=1.4037 train_acc=0.2758 val_acc=0.4172 val_macro_auc=0.8296
# Epoch 18/50 -> train_loss=1.3953 val_loss=1.3617 train_acc=0.3539 val_acc=0.4724 val_macro_auc=0.8411
# Epoch 19/50 -> train_loss=1.4151 val_loss=1.3517 train_acc=0.2806 val_acc=0.4663 val_macro_auc=0.8498
# Epoch 20/50 -> train_loss=1.3534 val_loss=1.3483 train_acc=0.3443 val_acc=0.4540 val_macro_auc=0.8533
# Epoch 21/50 -> train_loss=1.3711 val_loss=1.3384 train_acc=0.3258 val_acc=0.4724 val_macro_auc=0.8587
# Epoch 22/50 -> train_loss=1.3157 val_loss=1.3001 train_acc=0.3388 val_acc=0.5092 val_macro_auc=0.8669
# Epoch 23/50 -> train_loss=1.3090 val_loss=1.2634 train_acc=0.3758 val_acc=0.5583 val_macro_auc=0.8707
# Epoch 24/50 -> train_loss=1.3450 val_loss=1.2827 train_acc=0.4292 val_acc=0.4785 val_macro_auc=0.8634
# Epoch 25/50 -> train_loss=1.3620 val_loss=1.3031 train_acc=0.4401 val_acc=0.4049 val_macro_auc=0.8666
# Epoch 26/50 -> train_loss=1.2249 val_loss=1.2602 train_acc=0.3265 val_acc=0.4969 val_macro_auc=0.8788
# Epoch 27/50 -> train_loss=1.3481 val_loss=1.2728 train_acc=0.3504 val_acc=0.4663 val_macro_auc=0.8754
# Epoch 28/50 -> train_loss=1.1609 val_loss=1.1994 train_acc=0.2710 val_acc=0.5644 val_macro_auc=0.8836
# Epoch 29/50 -> train_loss=1.2303 val_loss=1.1680 train_acc=0.4456 val_acc=0.5951 val_macro_auc=0.8827
# Epoch 30/50 -> train_loss=1.1874 val_loss=1.1340 train_acc=0.4059 val_acc=0.5828 val_macro_auc=0.8878
# Epoch 31/50 -> train_loss=1.1522 val_loss=1.2035 train_acc=0.3662 val_acc=0.5031 val_macro_auc=0.8808
# Epoch 32/50 -> train_loss=1.1722 val_loss=1.2228 train_acc=0.3669 val_acc=0.5031 val_macro_auc=0.8911
# Epoch 33/50 -> train_loss=1.0904 val_loss=1.1274 train_acc=0.2710 val_acc=0.5890 val_macro_auc=0.8954
# Epoch 34/50 -> train_loss=1.1026 val_loss=1.0687 train_acc=0.4613 val_acc=0.6135 val_macro_auc=0.8885
# Epoch 35/50 -> train_loss=1.1155 val_loss=1.0123 train_acc=0.4654 val_acc=0.6442 val_macro_auc=0.9084
# Epoch 36/50 -> train_loss=1.0891 val_loss=1.0594 train_acc=0.4339 val_acc=0.6135 val_macro_auc=0.9017
# Epoch 37/50 -> train_loss=1.1450 val_loss=1.0393 train_acc=0.3867 val_acc=0.6196 val_macro_auc=0.9034
# Epoch 38/50 -> train_loss=1.1846 val_loss=1.0092 train_acc=0.4956 val_acc=0.6258 val_macro_auc=0.9084
# Epoch 39/50 -> train_loss=1.0207 val_loss=1.0151 train_acc=0.4216 val_acc=0.6074 val_macro_auc=0.9142
# Epoch 40/50 -> train_loss=1.0384 val_loss=0.9649 train_acc=0.4374 val_acc=0.6810 val_macro_auc=0.9107
# Epoch 41/50 -> train_loss=1.1252 val_loss=0.9947 train_acc=0.3292 val_acc=0.6442 val_macro_auc=0.9041
# Epoch 42/50 -> train_loss=1.0273 val_loss=1.0232 train_acc=0.3614 val_acc=0.6074 val_macro_auc=0.9160
# Epoch 43/50 -> train_loss=1.0036 val_loss=1.4249 train_acc=0.3238 val_acc=0.3742 val_macro_auc=0.8592
# Epoch 44/50 -> train_loss=1.1242 val_loss=0.9341 train_acc=0.4914 val_acc=0.6871 val_macro_auc=0.9114
# Epoch 45/50 -> train_loss=1.0351 val_loss=0.9380 train_acc=0.4230 val_acc=0.6442 val_macro_auc=0.9068
# Epoch 46/50 -> train_loss=1.0290 val_loss=1.0243 train_acc=0.4990 val_acc=0.6196 val_macro_auc=0.9014
# Epoch 47/50 -> train_loss=1.0372 val_loss=0.9312 train_acc=0.4203 val_acc=0.6933 val_macro_auc=0.9220
# Epoch 48/50 -> train_loss=1.1219 val_loss=1.1646 train_acc=0.4052 val_acc=0.4969 val_macro_auc=0.8804
# Epoch 49/50 -> train_loss=1.0289 val_loss=0.9601 train_acc=0.3812 val_acc=0.6810 val_macro_auc=0.9193
# Epoch 50/50 -> train_loss=0.9099 val_loss=0.9397 train_acc=0.4394 val_acc=0.6626 val_macro_auc=0.9140
# Saved training history to split_results/history_9-90.csv
# Saved loss curve to split_results/loss_curve_9-90.png
# Saved accuracy curve to split_results/acc_curve_9-90.png
# Saved ROC AUC curve to split_results/roc_auc_curve_9-90.png
#
# Classification report for split 9-90
#               precision    recall  f1-score       support
# CD             0.727205  0.633051  0.676870   1537.000000
# HYP            0.217854  0.551867  0.312390    482.000000
# MI             0.490351  0.546292  0.516812   2279.000000
# NORM           0.882392  0.652659  0.750335   8162.000000
# STTC           0.455954  0.735648  0.562976   2160.000000
# accuracy       0.642955  0.642955  0.642955      0.642955
# macro avg      0.554751  0.623904  0.563876  14620.000000
# weighted avg   0.720053  0.642955  0.664090  14620.000000
#
# Saved results to split_results
#    split  train_size  val_size  test_size  test_loss  test_acc  macro_auc  \
# 0  90-10       13157      1462       1625   0.718959  0.747077   0.928637
# 1  80-20       11695      1300       3249   0.736863  0.739304   0.928471
# 2  70-30       10233      1137       4874   0.714827  0.757078   0.921565
# 3  60-40        8771       975       6498   0.778136  0.727608   0.917078
# 4  50-50        7309       813       8122   0.780865  0.739350   0.904883
# 5  40-60        5847       650       9747   0.807611  0.715913   0.912667
# 6  30-70        4385       488      11371   0.879880  0.685076   0.902031
# 7  19-80        2923       325      12996   0.885879  0.686596   0.887831
# 8   9-90        1461       163      14620   1.021640  0.642955   0.864885
#
#                                        per_class_auc
# 0  {'CD': 0.9502883756847414, 'HYP': 0.9050852252...
# 1  {'CD': 0.9426148216545263, 'HYP': 0.9384819479...
# 2  {'CD': 0.92763631576685, 'HYP': 0.919731731842...
# 3  {'CD': 0.9299544647117253, 'HYP': 0.9186035443...
# 4  {'CD': 0.9281236990226316, 'HYP': 0.9102643771...
# 5  {'CD': 0.9289987192465367, 'HYP': 0.9190599607...
# 6  {'CD': 0.9287907274863797, 'HYP': 0.8904777494...
# 7  {'CD': 0.9109769377676001, 'HYP': 0.8798935659...
# 8  {'CD': 0.9051836154841635, 'HYP': 0.8229393694...

# %%
import os, math
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display, Image

OUT_DIR = "split_results"
files = sorted([f for f in os.listdir(OUT_DIR) if f.startswith("history_") and f.endswith(".csv")])
if not files:
    print("No history_*.csv files found in", OUT_DIR)
for fname in files:
    split_name = fname.replace("history_","").replace(".csv","")
    path = os.path.join(OUT_DIR, fname)
    df = pd.read_csv(path)
    print(f"\n=== {split_name} ({len(df)} epochs) ===")
    # loss
    plt.figure(figsize=(6,3))
    plt.plot(df['epoch'], df['train_loss'], label='train_loss')
    plt.plot(df['epoch'], df['val_loss'], label='val_loss')
    plt.title(f'Loss - {split_name}'); plt.legend(); plt.grid(True); plt.show()
    # acc
    plt.figure(figsize=(6,3))
    plt.plot(df['epoch'], df['train_acc'], label='train_acc')
    plt.plot(df['epoch'], df['val_acc'], label='val_acc')
    plt.title(f'Accuracy - {split_name}'); plt.legend(); plt.grid(True); plt.show()
    # auc
    if 'val_macro_auc' in df.columns:
        val_aucs = df['val_macro_auc'].tolist()
        val_aucs = [float(x) if (not (isinstance(x, str) and x.lower()=='nan')) else float('nan') for x in val_aucs]
        plt.figure(figsize=(6,3))
        plt.plot(df['epoch'], val_aucs, marker='o', label='val_macro_auc')
        plt.title(f'Val Macro AUC - {split_name}'); plt.ylim(0,1.05); plt.grid(True); plt.show()
    # show ROC image if present
    roc_img = os.path.join(OUT_DIR, f"roc_curves_{split_name}.png")
    if os.path.exists(roc_img):
        display(Image(roc_img))
    else:
        print("No ROC image for", split_name)
# Out:
# === 19-80 (50 epochs) ===
# === 30-70 (50 epochs) ===
# === 40-60 (50 epochs) ===
# === 50-50 (50 epochs) ===
# === 60-40 (50 epochs) ===
# === 70-30 (50 epochs) ===
# === 80-20 (50 epochs) ===
# === 9-90 (50 epochs) ===
# === 90-10 (50 epochs) ===
